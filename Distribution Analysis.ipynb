# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Load the data
file_path = 'buildings_with_population_features.xlsx'
data = pd.read_excel(file_path, engine='openpyxl')

# Summary statistics
summary_stats = data.describe()
print("Summary Statistics:\n", summary_stats)

# Histogram for each numerical feature
numerical_features = data.select_dtypes(include=['float64', 'int64']).columns

for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(data[feature], kde=True)
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# Box plot for each numerical feature
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=data[feature])
    plt.title(f'Box Plot of {feature}')
    plt.xlabel(feature)
    plt.show()

# Density plot for each numerical feature
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.kdeplot(data[feature], shade=True)
    plt.title(f'Density Plot of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Density')
    plt.show()

# Q-Q plot for each numerical feature
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    stats.probplot(data[feature], dist="norm", plot=plt)
    plt.title(f'Q-Q Plot of {feature}')
    plt.xlabel('Theoretical Quantiles')
    plt.ylabel('Sample Quantiles')
    plt.show()
# Out:
# Summary Statistics:
#                area  road_density  building_category  building_density  \
# count  1000.000000   1000.000000        1000.000000       1000.000000
# mean    125.210596   2535.132000           1.545000        123.031000
# std      43.395388    553.611501           1.108695         43.961308
# min      50.001745   1501.000000           0.000000         50.000000
# 25%      87.618014   2094.250000           1.000000         85.750000
# 50%     126.252171   2556.000000           2.000000        121.500000
# 75%     162.267436   2998.250000           3.000000        160.250000
# max     199.833892   3498.000000           3.000000        200.000000
#
#        nearest_service_distance  service_access_stage       height  population
# count               1000.000000           1000.000000  1000.000000   1000.0000
# mean                   3.314275              5.500000    43.824864    243.1700
# std                    1.789416              2.873719    20.163390    147.0073
# min                    0.049119              1.000000    10.017005      1.0000
# 25%                    1.960459              3.000000    26.172286    108.0000
# 50%                    3.123133              5.500000    43.323953    246.0000
# 75%                    4.357224              8.000000    60.907026    372.0000
# max                   11.050676             10.000000    79.819606    498.0000
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
# /var/folders/d2/vfvjx2nn47d77zlp4l9ql4_40000gn/T/ipykernel_84839/539269526.py:36: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[feature], shade=True)
